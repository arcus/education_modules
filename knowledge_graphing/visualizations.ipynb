# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from pyvis.network import Network

# %%
# %load graph_data.py

G = nx.DiGraph()
G.add_node("bash_103_combining_commands", title="Bash: Combining Commands", author="Elizabeth Drellich and Nicole Feldman", estimated_time="30 minutes")
G.add_node("bash_command_line_101", title="Bash / Command Line 101", author="Nicole Feldman and Elizabeth Drellich", estimated_time="40 minutes")
G.add_node("bash_command_line_102", title="Bash: Searching and Organizing Files", author="Nicole Feldman and Elizabeth Drellich", estimated_time="30 minutes")
G.add_node("bash_conditionals_loops", title="Bash: Conditionals and Loops", author="Elizabeth Drellich", estimated_time="1 hour")
G.add_node("bash_scripts", title="Bash: Reusable Scripts", author="Elizabeth Drellich", estimated_time="1 hour")
G.add_node("citizen_science", title="Citizen Science", author="Rose Hartman", estimated_time="45 minutes")
G.add_node("data_management_basics", title="Research Data Management Basics", author="Ene Belleh", estimated_time="40 minutes")
G.add_node("data_storage_models", title="Types of Data Storage Solutions", author="Nicole Feldman", estimated_time="30 minutes")
G.add_node("data_visualization_in_ggplot2", title="Data Visualization in ggplot2", author="Rose Hartman", estimated_time="60 min")
G.add_node("data_visualization_in_open_source_software", title="Data Visualization in Open Source Software", author="Rose Hartman", estimated_time="20 minutes")
G.add_node("data_visualization_in_seaborn", title="Data Visualization in seaborn", author="Rose Hartman", estimated_time="1 hour")
G.add_node("database_normalization", title="Database Normalization", author="Joy Payton", estimated_time="40 minutes")
G.add_node("demystifying_geospatial_data", title="Demystifying Geospatial Data", author="Elizabeth Drellich", estimated_time="15 minutes")
G.add_node("demystifying_python", title="Demystifying Python", author="Meredith Lee", estimated_time="20m")
G.add_node("demystifying_sql", title="Demystifying SQL", author="Peter Camacho", estimated_time="40 minutes")
G.add_node("directories_and_file_paths", title="Directories and File Paths", author="Meredith Lee", estimated_time="15m")
G.add_node("elements_of_maps", title="The Elements of Maps", author="Elizabeth Drellich", estimated_time="45 minutes")
G.add_node("geocode_lat_long", title="Encoding Geospatial Data: Latitude and Longitude", author="Elizabeth Drellich", estimated_time="15 minutes")
G.add_node("git_creation_and_tracking", title="Creating a Git Repository", author="Elizabeth Drellich", estimated_time="1 hour")
G.add_node("git_history_of_project", title="Exploring the History of your Git Repository", author="Elizabeth Drellich", estimated_time="30 minutes")
G.add_node("git_intro", title="Intro to Version Control", author="Rose Hartman", estimated_time="10 min")
G.add_node("git_setup_mac_and_linux", title="Setting Up Git on Mac and Linux", author="Rose Hartman", estimated_time="15 min")
G.add_node("git_setup_windows", title="Setting Up Git on Windows", author="Elizabeth Drellich", estimated_time="25 min")
G.add_node("how_to_troubleshoot", title="How to Troubleshoot", author="Joy Payton", estimated_time="30 minutes")
G.add_node("learning_to_learn", title="Learning to Learn Data Science", author="Rose Franzen", estimated_time="20 minutes")
G.add_node("omics_orientation", title="Omics Orientation", author="Meredith Lee", estimated_time="15m")
G.add_node("pandas_transform", title="Transform Data with pandas", author="Elizabeth Drellich", estimated_time="1 hour")
G.add_node("python_basics_writing_python_code", title="Python Basics: Writing Python Code", author="Meredith Lee", estimated_time="1 hour")
G.add_node("python_practice", title="Python Practice", author="Meredith Lee", estimated_time="1 hour")
G.add_node("r_basics_introduction", title="R Basics: Introduction", author="Joy Payton", estimated_time="1 hour")
G.add_node("r_basics_transform_data", title="R Basics: Transforming Data With dplyr", author="Joy Payton", estimated_time="1 hour")
G.add_node("r_basics_visualize_data", title="R Basics: Visualizing Data With ggplot2", author="Joy Payton", estimated_time="1 hour")
G.add_node("r_missing_values", title="Missing Values in R", author="Rose Hartman", estimated_time="45 min")
G.add_node("r_practice", title="R Practice", author="Meredith Lee", estimated_time="1 hour")
G.add_node("r_reshape_long_wide", title="Reshaping Data in R: Long and Wide Data", author="Joy Payton", estimated_time="1 hour")
G.add_node("reproducibility", title="Reproducibility, Generalizability, and Reuse", author="Joy Payton", estimated_time="1 hour")
G.add_node("sql_basics", title="SQL Basics", author="Peter Camacho", estimated_time="1 hour")
G.add_node("sql_intermediate", title="SQL, Intermediate Level", author="Peter Camacho", estimated_time="1 hour")
G.add_node("sql_joins", title="SQL Joins", author="Joy Payton", estimated_time="1 hour")
G.add_node("statistical_tests", title="Statistical Tests in Open Source Software", author="Rose Hartman", estimated_time="20 minutes (although reading through the linked tutorials may take much longer, depending on which tests you choose to read about)")
G.add_node("tidy_data", title="Tidy Data", author="Joy Payton", estimated_time="45 minutes")
G.add_node("using_redcap_api", title="Using the REDCap API", author="Joy Payton", estimated_time="1 hour")
G.add_edge("bash_103_combining_commands", "bash_command_line_101", link_type="internal_link")
G.add_edge("bash_103_combining_commands", "bash_command_line_102", link_type="internal_link")
G.add_edge("bash_103_combining_commands", "directories_and_file_paths", link_type="internal_link")
G.add_edge("bash_command_line_101", "directories_and_file_paths", link_type="internal_link")
G.add_edge("bash_command_line_101", "git_setup_windows", link_type="internal_link")
G.add_edge("bash_command_line_102", "bash_command_line_101", link_type="internal_link")
G.add_edge("bash_command_line_102", "directories_and_file_paths", link_type="internal_link")
G.add_edge("bash_conditionals_loops", "bash_command_line_101", link_type="internal_link")
G.add_edge("bash_conditionals_loops", "bash_command_line_102", link_type="internal_link")
G.add_edge("bash_conditionals_loops", "directories_and_file_paths", link_type="internal_link")
G.add_edge("bash_scripts", "bash_command_line_101", link_type="internal_link")
G.add_edge("bash_scripts", "reproducibility", link_type="internal_link")
G.add_edge("data_management_basics", "reproducibility", link_type="internal_link")
G.add_edge("data_visualization_in_ggplot2", "data_visualization_in_open_source_software", link_type="internal_link")
G.add_edge("data_visualization_in_ggplot2", "data_visualization_in_seaborn", link_type="internal_link")
G.add_edge("data_visualization_in_ggplot2", "r_basics_introduction", link_type="internal_link")
G.add_edge("data_visualization_in_ggplot2", "statistical_tests", link_type="internal_link")
G.add_edge("data_visualization_in_open_source_software", "data_visualization_in_ggplot2", link_type="internal_link")
G.add_edge("data_visualization_in_open_source_software", "data_visualization_in_seaborn", link_type="internal_link")
G.add_edge("data_visualization_in_open_source_software", "demystifying_python", link_type="internal_link")
G.add_edge("data_visualization_in_open_source_software", "r_basics_introduction", link_type="internal_link")
G.add_edge("data_visualization_in_seaborn", "data_visualization_in_ggplot2", link_type="internal_link")
G.add_edge("data_visualization_in_seaborn", "demystifying_python", link_type="internal_link")
G.add_edge("data_visualization_in_seaborn", "statistical_tests", link_type="internal_link")
G.add_edge("demystifying_python", "bash_command_line_101", link_type="internal_link")
G.add_edge("demystifying_python", "python_basics_writing_python_code", link_type="internal_link")
G.add_edge("demystifying_sql", "reproducibility", link_type="internal_link")
G.add_edge("git_creation_and_tracking", "git_setup_mac_and_linux", link_type="internal_link")
G.add_edge("git_creation_and_tracking", "git_setup_windows", link_type="internal_link")
G.add_edge("git_history_of_project", "git_creation_and_tracking", link_type="internal_link")
G.add_edge("git_setup_mac_and_linux", "git_setup_windows", link_type="internal_link")
G.add_edge("git_setup_windows", "git_setup_mac_and_linux", link_type="internal_link")
G.add_edge("learning_to_learn", "reproducibility", link_type="internal_link")
G.add_edge("pandas_transform", "python_basics_writing_python_code", link_type="internal_link")
G.add_edge("python_basics_writing_python_code", "demystifying_python", link_type="internal_link")
G.add_edge("python_practice", "data_visualization_in_seaborn", link_type="internal_link")
G.add_edge("python_practice", "demystifying_python", link_type="internal_link")
G.add_edge("python_practice", "pandas_transform", link_type="internal_link")
G.add_edge("python_practice", "python_basics_writing_python_code", link_type="internal_link")
G.add_edge("python_practice", "r_practice", link_type="internal_link")
G.add_edge("r_basics_introduction", "r_basics_transform_data", link_type="internal_link")
G.add_edge("r_basics_introduction", "r_basics_visualize_data", link_type="internal_link")
G.add_edge("r_basics_introduction", "reproducibility", link_type="internal_link")
G.add_edge("r_basics_transform_data", "r_basics_introduction", link_type="internal_link")
G.add_edge("r_basics_transform_data", "r_basics_visualize_data", link_type="internal_link")
G.add_edge("r_basics_visualize_data", "data_visualization_in_ggplot2", link_type="internal_link")
G.add_edge("r_basics_visualize_data", "r_basics_introduction", link_type="internal_link")
G.add_edge("r_basics_visualize_data", "r_basics_transform_data", link_type="internal_link")
G.add_edge("r_basics_visualize_data", "tidy_data", link_type="internal_link")
G.add_edge("r_missing_values", "r_basics_introduction", link_type="internal_link")
G.add_edge("r_missing_values", "r_basics_transform_data", link_type="internal_link")
G.add_edge("r_practice", "data_visualization_in_ggplot2", link_type="internal_link")
G.add_edge("r_practice", "python_practice", link_type="internal_link")
G.add_edge("r_practice", "r_basics_introduction", link_type="internal_link")
G.add_edge("r_practice", "r_basics_transform_data", link_type="internal_link")
G.add_edge("r_reshape_long_wide", "r_basics_introduction", link_type="internal_link")
G.add_edge("r_reshape_long_wide", "r_basics_transform_data", link_type="internal_link")
G.add_edge("r_reshape_long_wide", "tidy_data", link_type="internal_link")
G.add_edge("sql_basics", "demystifying_sql", link_type="internal_link")
G.add_edge("sql_intermediate", "demystifying_sql", link_type="internal_link")
G.add_edge("sql_intermediate", "sql_basics", link_type="internal_link")
G.add_edge("sql_joins", "database_normalization", link_type="internal_link")
G.add_edge("sql_joins", "sql_basics", link_type="internal_link")
G.add_edge("sql_joins", "sql_intermediate", link_type="internal_link")
G.add_edge("statistical_tests", "data_visualization_in_open_source_software", link_type="internal_link")
G.add_edge("statistical_tests", "python_basics_writing_python_code", link_type="internal_link")
G.add_edge("statistical_tests", "r_basics_introduction", link_type="internal_link")
G.add_edge("tidy_data", "reproducibility", link_type="internal_link")
G.add_edge("using_redcap_api", "reproducibility", link_type="internal_link")

# %%
G.nodes.data()



pos = nx.spiral_layout(G)

authors = [G.nodes[u]["author"] for u in G.nodes()]
titles = {u:G.nodes[u]["title"] for u in G.nodes()}
estimated_time = {u:G.nodes[u]["estimated_time"][0:2] for u in G.nodes()}

nx.draw(G, pos = pos, with_labels=False)

my_modules = [u for u in G.nodes() if "Elizabeth Drellich" in str(G.nodes[u]["author"])]

my_modules

H = G.subgraph(my_modules)
titles = {u:H.nodes[u]["title"] for u in H.nodes()}
nx.draw(H, with_labels = True, pos=pos, font_size=10, node_color="red", node_size=200, labels = titles)

Joy_modules = [u for u in G.nodes() if "Joy Payton" in str(G.nodes[u]["author"])]

J = G.subgraph(Joy_modules)
titles = {u:J.nodes[u]["title"] for u in J.nodes()}
nx.draw(J, with_labels = True, pos=pos, font_size=10, node_color="yellow", node_size=200, labels = titles)

# %%
## Create estimated time list so that node size can be scaled by time
estimated_time = {u:G.nodes[u]["estimated_time"][0:2] for u in G.nodes()}

times = []
for est_time in list(estimated_time.values()):
    if int(est_time) == 1:
        times.append(int(60))
    else:
        times.append(int(est_time))
times=[i * 5 for i in times]

## Create Author Colors so that nodes can be colored by author
authors = {u:G.nodes[u]["author"] for u in G.nodes()}

authors.values()
# Out:
# dict_values(['Elizabeth Drellich and Nicole Feldman', 'Nicole Feldman and Elizabeth Drellich', 'Nicole Feldman and Elizabeth Drellich', 'Elizabeth Drellich', 'Elizabeth Drellich', 'Rose Hartman', 'Ene Belleh', 'Nicole Feldman', 'Rose Hartman', 'Rose Hartman', 'Rose Hartman', 'Joy Payton', 'Elizabeth Drellich', 'Meredith Lee', 'Peter Camacho', 'Meredith Lee', 'Elizabeth Drellich', 'Elizabeth Drellich', 'Elizabeth Drellich', 'Elizabeth Drellich', 'Rose Hartman', 'Rose Hartman', 'Elizabeth Drellich', 'Joy Payton', 'Rose Franzen', 'Meredith Lee', 'Elizabeth Drellich', 'Meredith Lee', 'Meredith Lee', 'Joy Payton', 'Joy Payton', 'Joy Payton', 'Rose Hartman', 'Meredith Lee', 'Joy Payton', 'Joy Payton', 'Peter Camacho', 'Peter Camacho', 'Joy Payton', 'Rose Hartman', 'Joy Payton', 'Joy Payton'])

# %%
nx.draw(G, pos = pos, with_labels=False, node_size=times)

# %%
for module in G.nodes():
    G.nodes.data()[module]['label'] = G.nodes.data()[module]['title']
    G.nodes.data()[module]['size'] = G.nodes.data()[module]['estimated_time'][0:2] if int(G.nodes.data()[module]['estimated_time'][0:2])>1 else 60
    

nt = Network('300px', '300px', filter_menu=True, directed=True)
# populates the nodes and edges data structures
nt.from_nx(G)
nt.show_buttons(filter_=['nodes', 'physics'])
nt.show('nx.html', notebook=False)
# Out:
# nx.html

# %%
import networkx as nx

from bokeh.io import output_file, show
from bokeh.models import (BoxZoomTool,BoxSelectTool, Circle, EdgesAndLinkedNodes, HoverTool,
                          MultiLine, NodesAndLinkedEdges, Plot, Range1d, TapTool,ResetTool,
                          HoverTool, Plot, Range1d, ResetTool, GraphRenderer, Ellipse)
from bokeh.palettes import Spectral4
from bokeh.plotting import from_networkx
from bokeh.io import output_notebook

output_notebook()

plot = Plot(width=400, height=400,
            x_range=Range1d(-1.1,1.1), y_range=Range1d(-1.1,1.1))
plot.title.text = "Graph Interaction Demonstration"

plot.add_tools(HoverTool(tooltips=None), TapTool(), BoxSelectTool())

node_hover_tool = HoverTool(tooltips=[("title", "@title"), ("author", "@author")])
plot.add_tools(node_hover_tool, BoxZoomTool(), ResetTool())

graph_renderer = from_networkx(G, nx.circular_layout, scale=1, center=(0,0))

graph_renderer.node_renderer.glyph = Circle(size=15, fill_color=Spectral4[0])
graph_renderer.node_renderer.selection_glyph = Circle(size=15, fill_color=Spectral4[2])
graph_renderer.node_renderer.hover_glyph = Circle(size=15, fill_color=Spectral4[1])

#graph_renderer.edge_renderer.glyph = MultiLine(line_color="#CCCCCC", line_alpha=0.8, line_width=5)
#graph_renderer.edge_renderer.selection_glyph = MultiLine(line_color=Spectral4[2], line_width=5)
#graph_renderer.edge_renderer.hover_glyph = MultiLine(line_color=Spectral4[1], line_width=5)

#graph_renderer.selection_policy = NodesAndLinkedEdges()
#graph_renderer.inspection_policy = EdgesAndLinkedNodes()

plot.renderers.append(graph_renderer)

#output_file("interactive_graphs.html")
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="61cfda59-4f27-43bd-ba8b-528b70953ec2" data-root-id="1005"></div>

# %%
import networkx as nx

from bokeh.io import output_file, show
from bokeh.models import (BoxZoomTool, Circle, HoverTool,
                          MultiLine, Plot, Range1d, ResetTool)
from bokeh.palettes import Spectral4
from bokeh.plotting import from_networkx

# Prepare Data
K = nx.karate_club_graph()

SAME_CLUB_COLOR, DIFFERENT_CLUB_COLOR = "black", "red"
edge_attrs = {}

#for start_node, end_node, _ in K.edges(data=True):
#    edge_color = SAME_CLUB_COLOR if K.nodes[start_node]["club"] == K.nodes[end_node]["club"] else DIFFERENT_CLUB_COLOR
#    edge_attrs[(start_node, end_node)] = edge_color

nx.set_edge_attributes(K, edge_attrs, "edge_color")

# Show with Bokeh
plot = Plot(width=400, height=400,
            x_range=Range1d(-1.1, 1.1), y_range=Range1d(-1.1, 1.1))
plot.title.text = "Graph Interaction Demonstration"

node_hover_tool = HoverTool(tooltips=[("index", "@index"), ("club", "@club")])
plot.add_tools(node_hover_tool, BoxZoomTool(), ResetTool())

graph_renderer = from_networkx(K, nx.spring_layout, scale=1, center=(0, 0))

graph_renderer.node_renderer.glyph = Circle(size=15, fill_color=Spectral4[0])
graph_renderer.edge_renderer.glyph = MultiLine(line_color="edge_color", line_alpha=0.8, line_width=1)
plot.renderers.append(graph_renderer)

output_file("interactive_graphs.html")
show(plot)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "line_color" value "edge_color" [renderer: GlyphRenderer(id='1205', ...)]
#   <div class="bk-root" id="636e9e9d-a570-4f96-a3ea-1169695b26ff" data-root-id="1188"></div>
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name. This could either be due to a misspelling or typo, or due to an expected column being missing. : key "line_color" value "edge_color" [renderer: GlyphRenderer(id='1205', ...)]

# %%
K.nodes.data()
# Out:
# NodeDataView({0: {'club': 'Mr. Hi'}, 1: {'club': 'Mr. Hi'}, 2: {'club': 'Mr. Hi'}, 3: {'club': 'Mr. Hi'}, 4: {'club': 'Mr. Hi'}, 5: {'club': 'Mr. Hi'}, 6: {'club': 'Mr. Hi'}, 7: {'club': 'Mr. Hi'}, 8: {'club': 'Mr. Hi'}, 9: {'club': 'Officer'}, 10: {'club': 'Mr. Hi'}, 11: {'club': 'Mr. Hi'}, 12: {'club': 'Mr. Hi'}, 13: {'club': 'Mr. Hi'}, 14: {'club': 'Officer'}, 15: {'club': 'Officer'}, 16: {'club': 'Mr. Hi'}, 17: {'club': 'Mr. Hi'}, 18: {'club': 'Officer'}, 19: {'club': 'Mr. Hi'}, 20: {'club': 'Officer'}, 21: {'club': 'Mr. Hi'}, 22: {'club': 'Officer'}, 23: {'club': 'Officer'}, 24: {'club': 'Officer'}, 25: {'club': 'Officer'}, 26: {'club': 'Officer'}, 27: {'club': 'Officer'}, 28: {'club': 'Officer'}, 29: {'club': 'Officer'}, 30: {'club': 'Officer'}, 31: {'club': 'Officer'}, 32: {'club': 'Officer'}, 33: {'club': 'Officer'}})

# %%
from dash import Dash, dcc, html, Input, Output

app = Dash(__name__)

app.layout = html.Div([
    html.H6("Change the value in the text box to see callbacks in action!"),
    html.Div([
        "Input: ",
        dcc.Input(id='my-input', value='initial value', type='text')
    ]),
    html.Br(),
    html.Div(id='my-output'),

])


@app.callback(
    Output(component_id='my-output', component_property='children'),
    Input(component_id='my-input', component_property='value')
)
def update_output_div(input_value):
    return f'Output: {input_value}'


if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [03/Apr/2023 10:43:53] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2023 10:43:53] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2023 10:43:53] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Apr/2023 10:43:53] "POST /_dash-update-component HTTP/1.1" 200 -
